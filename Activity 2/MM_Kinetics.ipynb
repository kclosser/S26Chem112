# %% [markdown]
# # Enzyme Kinetics

# %% [markdown]
# Adapted for Chem 112 by Dr. Closser from activity by Prof. Allyn Schoeffler https://aschoef.wixsite.com/schoefflerlab/general-8
#
# Enzymes catalyze many medically important reactions in biology. We are often interested in knowing which enzymes catalyze which reactions, because this can help us map metabolic pathways and understand what happens when they are perturbed by genetic mutations, malignant transformation, or toxins.
#
# Knowing which enzymes do what is only part of enzymology. It's also useful to know how good they are at their jobs. How fast do they work, and how specific are they? Can they work on only one substrate, or lots of different substrates? Can they be stopped or inhibited? Quantitative enzymology is the study of these questions. In this field, we use mathematical models to describe enzyme speed and efficiency.
#
# ## Prerequisites
#
# This notebook assumes users are familiar with basic kinetics concepts
# and the following python/Jupyter skills
#
# - defining and using variables
# - Performing basic mathematical operations
# - basic plotting with matplotlib
# - basic usage of numpy
# - defining functions
#
# ## Content Objectives
#
# After completing this exercise you should be able to
#
# - explain the significance of all the parameters in the Michaelis-Menten model
# - predict the impact of enzyme concentration on $K_M$ and $V_{max}$
#
#
# ## Process Objectives
#
# After completing this exercise you should be able to use python to
#
# - read in and display data
# - create a customized non-linear fitting model and use this model to fit data
# - define fittable parameters and non-linear fitting
# - compare fitting models

# %% [markdown]
# ## Background
#
# In order to undestand the kinetics of enzymes, we must start with a general form of and enzymatic reaction.

# %% [markdown]
# $$ E + S \rightleftharpoons ES \rightarrow E + P$$

# %% [markdown]
# Many enzymes follow the general reaction above. First, they bind to a substrate ($S$) and form an enzyme-substrate complex ($ES$). This step is usually considered revserible. Then, catalysis occurrs, converting the substrate ($S$) to product ($P$). The enzyme releases the product, and then it is a free enzyme again ($E$), ready to accept another substrate. The rate constants that describe each step are as follows:
#
# - $k_1$ is the rate constant for the enzyme-substrate association step.
# - $k_{-1}$ is the rate constant for the enzyme-substrate dissociation step.
# - $k_2$, usually called $k_{cat}$, is the rate constant for the product formation step. (In this case, "$cat$" stands for "catalysis.)
#
# We can define an enzyme's velocity as how fast it performs catalysis. Another way to say this would be that enzyme speed is equal to the change in product concetration per unit time. This is a chemical rate, and we can use the rules of chemical rate laws to write a rate equation for product formation:

# %% [markdown]
# $$ \frac{{d[P]}}{dt} = k_{cat}[ES]$$

# %% [markdown]
# In this equation, $\frac{{d[P]}}{dt}$ is the same thing as velocity ($V$).
#
# By using the rules of rate laws and some algebraic manipulation, we can arrive at the Michaleis-Menten equation, which makes several assumptions along the way, and collapses some of the rate constants into a composite term called the Michaelis constant.
#
# The Michaelis-Menten equation:

# %% [markdown]
# $$ V_o = \frac{{V_{max} [S]}}{K_M + [S]}  $$
#
# In this equation,
#
# $$ V_o = initial\ velocity $$
# $$ V_{max} = maximum\ velocity $$
# $$[S] = substrate\ concentration $$
# $$K_M = Michaelis\ constant $$
#
# The $V_{max}$ and $K_M$ terms are "shorthand" variables for more complex terms. Their full definitions follow:
#
# $$V_{max} = k_{cat}[E]_t$$
#
#
# $$K_M = \frac{{(k_{-1} + k_2)}}{k_1}$$
#
# These definitions imply a couple of important things about the Michaelis-Menten equation, but one of the most important is that the $V_{max}$ is a theoretical limit. It's the speed the enzyme would reach if every single enzyme in solution was bound to substrate, that is, if
#
#
# $$ [ES] = [E]_{total} $$
#
# Another interesting thing about the Michaelis-Menten model is that $K_M$, mathematically speaking, ends up being equal to the concentration of substrate at which the enzyme is at $\frac{{1}}{2} V_{max}$. Under certain conditions--when $k_2$ is negligible compared to $k_{-1}$--$K_M$ approxmates $K_D$, which is a measure of affinity. $K_M$ is thus often considered a measure of the strength of an enzyme's affinity for substrate (the strength of substrate binding). The smaller the value, the less substrate is required to drive the reaction, and therefore the stronger the affinity.
#
# Enzymologists often consider $K_{M}$ and $k_{cat}$ together as a measure of enzyme efficiency. Becasue a large $k_{cat}$ means the enzyme is fast, and a small $K_{M}$ means the enzyme is good at binding substrate, the ratio of $k_{cat}$ to $K_{M}$ is a general measure of enzyme awesomeness, the specificity constant:
#
# $$specificity\ constant = \frac{{k_{cat}}}{K_M}$$
#
#
# Biochemists sometimes try to determine specificty constants for an enzyme on multiple substrates to try and understand which substrate is best.
#
# For more information and a full explanation of the derivation, see: https://bio.libretexts.org/Courses/Wheaton_College_Massachusetts/Principles_of_Biochemistry/07%3A_Enzymes_catalysis_and_kinetics/7.02%3A_Derivation_of_Michaelis-Menten_equation

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <strong>Important notes</strong>
#
# WU = Warm Up questions; CTQ = Critical Thinking Questions.
#
# Remember that cells must be evaluated in order for variables to be defined as expected
# </div>

# %% [markdown]
# ## Warm Up Questions
#
# **WU 1** What assumptions are made in the derivation of the Michaelis-Menten equation?

# %% [markdown]
# **WU 2** Explain using full sentences the significance of the values of $V_0$, $V_{max}$, $K_M$ and $k_{cat}$. Include typical units for each of these.

# %% [markdown]
# **WU 3** What type of data must be collected experimentally to determine the kinetics of an enzyme reaction?

# %% [markdown]
# **WU 4** When performing a generic *linear* fit $y = mx+b$, what parameters are determined by the fit? What values are determined by the data?

# %% [markdown]
# **WU 5** When doing a linear fit, what parameter is most often used to assess the quality of the fit?

# %% [markdown]
# **WU 6** For non-linear data, there are two ways to fit the data (1) linearize the data and then perform a linear fit and (2) directly perform a non-linear fit. What are there benefits or drawbacks to each of these methods?

# %% [markdown]
# ## 1. Interactive Plots
#
# The simulations below will help you understand the Michaelis-Menten model and the parameters that define it. You do not need to do anything with this code directly! Once you run the cell, scroll down to the output and then you can adjust the parameters.
#
# The graph below shows a plot of the Michaelis-Menten function, and you can adjust $K_M$ and $V_{max}$ to see what happens to the shape of the curve.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import ipywidgets as widgets

out = widgets.Output()

Et = 0.1
KM = widgets.FloatText(value = 2, continuous_update=False, description = '$K_{M}:$')
Vmax = widgets.FloatText(value = 10, continuous_update=False, description = '$V_{max}:$')

plotbutton = widgets.Button(description = "Update Plot")

subs = np.linspace(0.001, 25, 1000)

@out.capture(clear_output = True, wait = True)
def mmplot(Vmax, KM, Et, subs):
    vels = Vmax*subs/(subs+KM)
    fig, ax = plt.subplots()
    plt.title ("Enzyme Activity")
    plt.xlabel ("[substrate] (mM)")
    plt.ylabel (r'$V_o\ (\ \frac{nmol\ product}{s})$')
    ax.set_ylim(0,10)
    plt.plot(subs,vels)
    plt.show()
    
KM.observe(lambda value: mmplot(Vmax.value, KM.value, Et, subs))
Vmax.observe(lambda value: mmplot(Vmax.value, KM.value, Et, subs))

mmplot(Vmax.value, KM.value, Et, subs)
vbox = widgets.VBox([KM, Vmax, plotbutton, out])
vbox

# %% [markdown]
# **CTQ 1** What happens to $V_0$ when $K_M$ increases? What is significance of a higher $K_M$ in an enzyme reaction?

# %% [markdown]
# **CTQ 2** What happens to $V_0$ when $V_{max}$ increases? What is significance of a higher $V_{max}$ in an enzyme reaction?

# %% [markdown]
# It's important to understand the $V_{max}$ is not a constant--it is dependent on enzyme concentration. $V_{max}$ is related to a constant, though, $k_{cat}$. Recall the following equation:
# $$V_{max} = k_{cat}[E]_t$$
#
# The simulation below gives you the ability to change $E_t$ and observe the effect on the plot. In this simulation, $k_{cat}$ and $K_M$ are held constant.

# %%
out = widgets.Output()

kcat = 0.01
Et = widgets.FloatText(value = 10, continuous_update=False, description = '$E_{t}:$')
KM = 5.0
Vmax = Et.value*kcat

plotbutton = widgets.Button(description = "Update Plot")

subs = np.linspace(0.001, 25, 1000)

@out.capture(clear_output = True, wait = True)
def mmplot(kcat, KM, Et, subs):
    vels = kcat*Et*subs/(subs+KM)
    fig, ax = plt.subplots()
    plt.title ("Enzyme Activity")
    plt.xlabel ("[substrate] (mM)")
    plt.ylabel (r'$V_o\ (\ \frac{nmol\ product}{s})$')
    ax.set_ylim(0,0.25)
    plt.plot(subs,vels)
    plt.show()
    
Et.observe(lambda value: mmplot(kcat, KM, Et.value, subs))

mmplot(kcat, KM, Et.value, subs)
vbox = widgets.VBox([Et, plotbutton, out])
vbox
#print("The $V_{max}$ is %f.2" % Vmax)

# %% [markdown]
# **CTQ 3** What happens when you double the total enzyme concentration?

# %% [markdown]
# **CTQ 4** Can you look at any of these curves and estimate $K_{M}$ and $V_{max}$? If so, what are you looking for, if not, why not?

# %% [markdown]
# ## 2. Linearizing Data: The Lineweaver-Burke Plot

# %% [markdown]
# To analyze enzyme activity data, you need to fit the data to determine the $K_M$ and $V_{max}$. One way to do this is to use the linearized version of the Michaelis-Menten equation, also called a double-reciprocal plot or a Lineweaver-Burk plot. Instead of plotting velocity vs. [substrate], you plot $\frac{{1}}{velocity}$ vs. $\frac{{1}}{[substrate]}$. This transformation leads to the Lineweaver-Burke equation:
#
# $$\dfrac{{1}}{V_o} = \dfrac{{K_M}}{V_{max}} \dfrac{{1}}{[S]} + \dfrac{{1}}{V_{max}}$$
#
# <div class="alert alert-block alert-warning">
# <strong>Important note</strong>
#
# Concentrations are given in millimolar (mM) units and velocities are in nanomoles of product per second (nmol product/s) throughout this activity
# </div>

# %% [markdown]
# **CTQ 5** What are the x and y axes in a Lineweaver-Burke plot? What are the slope and intercept?

# %% [markdown]
# **CTQ 6** Experimentally, what is the independent variable and what is the dependent variable for a general Michaelis-Menten experiment?

# %%
# import libraries and view Enzyme Data file
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# View the first 5 lines of file
# !head -n 5 EnzymeData.csv

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Excerise 1</strong>
#
# a) Modify this code to view and import the enzyme data into numpy arrays. Rename the columns to use meaningful names.
#
# b) Plot the data to visualize the enzyme velocity as a function of [S].
# </div>

# %%
# Import enzyme data
Col1, Col2, Col3 = np.genfromtxt('filename.csv', delimiter='some delimiter', unpack=True, skip_header=1)

# Plot Enzyme Velocity vs. Substrate Concentration 
# Look at Intro Computatational assignment for more information on plotting

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Excerise 2</strong>
#
# Add error bars based on the standard deviation to the plot using the `errorbar` function from matplotlib. The structure of the function is given, but you will need to define the x and y values, standard deviations and the format options. More information: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.errorbar.html
# </div>

# %%
# Plot with error bars, add appropriate axes labels
plt.errorbar(xvals, yvals, yerr = stdev, fmt = "", capsize = )
plt.show()

# %% [markdown]
# These errors must also be tranformed when the data is linearized. An approximate way of doing this is to evaluate the standard deviation divided by the value squared.
#
# $$A \pm \sigma_A\rightarrow \frac{1}{A}\pm \frac{\sigma_A}{A^2}$$
#
# <div class="alert alert-block alert-success">
# <strong>Excerise 3</strong>
#
# Generate a Lineweaver-Burke plot of the data with transformed error bars.
# </div>

# %%
# Linearized plot with error bars

# %% [markdown]
# **CTQ 7** What happens to the error as the 1/[S] increases? What implications does this have for the Michaelis-Menten model?

# %% [markdown]
# The error in a linear fit is often quantified using the variance, which is defined as
# $$ variance = s^2 = \sum_i{\frac{ (y_i-\bar{y})^2}{N-1}}$$
#
# where $\bar{y}$ is the value computed from the fit, and $N$ is the number of points used in fitting.
#
# The numerator $\sum_i{ (y_i-\bar{y})^2}$ is also known as the residual sum of squares
#
# <div class="alert alert-block alert-success">
# <strong>Excerise 4</strong>
#
# a) Using the `polyfit` function from Activity 1, create a linear fit of this data
#
# b) Generate a plot showing the original data and the linear fit.
#
# c) Calculate the residual sum of squares and variance of the linear fit
#
# </div>

# %%
import numpy as np
from numpy.polynomial.polynomial import polyfit, polyval, Polynomial

n =    # what degree of polynomial is used for a linear fit?

# define x and y values, you can rename these if desired
xvals = 
yvals = 

# generate linear fit and calculate theoretical y values associated with given x values
linearfit = 
linearfitvalues = 

# plot the original data and the linear fit

# %%
# calculate the variance of the linear fit

# %% [markdown]
# **CTQ 8** How good is the linear fit? How do you know?

# %% [markdown]
# **CTQ 9** Is the intrinsic error in the data points included in the variance of the linear fit? Why or why not?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Excerise 5</strong>
#
# Generate python code code to print the slope and intercept from the linear fit including reasonable units. Note that the first value in the fit can be accessed as `fit[0]`  and corresponds to the intercept and the second value `fit[1]` corresponds to the slope. Also, use the slope and intercept to calculate $K_M$ and $V_{max}$.
# </div>

# %%
# print slope and intercept, including units

# calculate K_m and V_max

# %% [markdown]
# ## 3. Nonlinear Fitting

# %% [markdown]
# You can also fit the data directly using a non-linear fit. The scipy library has a function that allows you to do this called `curve_fit`. In order to use this fitting function you need to define the function you want to use for fitting.

# %% [markdown]
# Recall the Michaelis-Menten equation is
# $V_o = \frac{{V_{max} [S]}}{K_M + [S]}$
#
# <div class="alert alert-block alert-success">
# <strong>Excerise 6</strong>
#
# Write a python function defining the Michaelis-Menten equation. An example defining a linear function is below.
#
# Test your Michaelis-Menten function by calling it with the following parameters
# - for [S] use `np.linspace(1,10,4)`
# - for $K_M$ use 5
# - for $V_{max}$ use 20
#
# If everything is correct you should print out an array with four numbers: 3.33333333,  8.88888889, 11.66666667, 13.33333333
# </div>

# %%
# example defining a linear function
def linear_function(x, m, b):
    y = m*x + b
    return y

xvals = np.linspace(1,10,2)
yvals = linear_function(xvals, 3, 1)
print(yvals)

# write a function defining the Michaelis-Menten model

# test Michaelis-Menten function

# %% [markdown]
# **CTQ 10** Explain why 4 values are printed by using the linspace command to generate [S] values. What happens if only one [S] value is used for the function?

# %% [markdown]
# **CTQ 11** In a linear fit the parameters are m and b (the slope and intercept). What values are being fit in the Michaelis-Menten model (i.e. the parameters in the non-linear fit)?

# %% [markdown]
# Now that you have a function that will calculate Michaelis-Menten y-values, you’re going to
# use it within the curve_fit function. Just like many Python functions, `curve_fit`
# accepts arguments, performs commands, and returns values. The arguments that
# `curve_fit` takes are, in order:
# 1. a custom Python function defining a mathematical equation (like the one you just made!)
# 2. an array of x values
# 3. an array of y values
#
# Also just like many functions, you should “store” the output of `curve_fit` in a new
# variable with a sensible name.
#
# To run `curve_fit` in this activity, you should pass it
# 1. your custom Michaelis-Menten function
# 2. the array of substrate concentration data
# 3. the array of velocity data.
#
# Store the output of in a new variable.
#
# The output of `curve_fit` is two lists. The first list contains the fitted parameters. They’re in the order you specified when you made your equation function. The second list contains covariation parameters, which can be used to estimate the quality of the fit.
#
#
#
# <div class="alert alert-block alert-success">
# <strong>Excerise 7</strong>
#
# Modify the code below to
# store the two fittable parameters in sensibly-named variables (one for each
# parameter).  Print the  parameters to make sure they
# make sense compared to those generated by the linear fit.
# </div>

# %%
from scipy.optimize import curve_fit # import curve fit function

#rename variables below to be useful!
params, covariance = curve_fit("replace this text with relevant function inputs--do not use quotes!") 

val1 = params[0]
val2 = params[1]

#print out values

# %% [markdown]
# The error in a non-linear fit is best assessed using a $\chi^2$ (chi-squared) value. It is defined as
# $$\chi^2 = \sum_{i=1}^n \frac{(O_i-E_i)^2}{E_i}$$
# where O is the observed or experimental value and E is the expected or theoretical value.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Excerise 8</strong>
#
# Calculate the chi-squared value for your *non-linear* fit.
# </div>

# %%
#Calculate and print out chi-squared

# %% [markdown]
# ## 4. Comparing models
#
# In order to compare different fits, you should use the same metric for both.
#
# <div class="alert alert-block alert-success">
# <strong>Excerise 9</strong>
#
# Calculate the chi-squared value for your *linear* fit.
# </div>

# %%
# calculate chi-squared for linear fit

# %% [markdown]
# **CTQ 12** How does the $\chi^2$ value compare to the residual sum of squares (rss) and the variance for a ***linear*** fit?

# %% [markdown]
# **CTQ 13** How does the $\chi^2$ value relate to a percent error calculation?

# %% [markdown]
# **CTQ 14** Considering both the error in the fitting itself, and the error associated with the individual data points, which fit method should be expected to give better results?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Excerise 10</strong>
#
# Write code to **quantify** the difference between $K_M$ obtained by linear fitting and $K_M$ obtained by non-linear fitting.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <strong>Excerise 11</strong>
#
# Write code to **quantify** the difference between $V_{max}$ obtained by linear fitting and $V_{max}$ obtained by non-linear fitting.
# </div>

# %% [markdown]
# **CTQ 15** How significant is the difference between $K_M$ values and $V_{max}$ values obtained using different fitting techniques?

# %% [markdown]
# ## Reflection
#
# Review the Content and Process Objectives at the beginning of the activity. Identify which of the objectives you feel you meet and those that may need more work; explain reasoning for your assessment.

# %% [markdown]
# Identify parts of the activity that stood out as surprising, interesting, or confusing, and explain why.

# %% [markdown]
# If you worked with anyone else, please give their names here.

# %% [markdown]
# What resources did you use for completing this activity? List them here.
